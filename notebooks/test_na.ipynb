# %%
import os, sys, importlib
import pandas as pd
import json
import networkx as nt
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'../results\vol1\vol1-combined_table-index_theme_notice.csv')
df.head()

# %% [markdown]
# ## vis1:
#
# mss+title_index为节点，(同一篇work可以有很多个点),出现在同一mss中的work之间相互连接，按照theme着色，观察因为mss clustering是否按照主题形成不同的组？
