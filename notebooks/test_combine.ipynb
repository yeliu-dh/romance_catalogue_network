# %%
import os, sys, importlib
sys.path.append(os.path.abspath(".."))
from utils import combine_tables
from utils.combine_tables import compile_combined_table

import json
import re

# %% [markdown]
# ## appli:

# %% [markdown]
# ### index table

# %%
## index_table(corrigé manuellement) => index_table_clean

path_index_table=r"../results\vol1\index_table_clean.json"
with open(path_index_table, 'r', encoding='utf-8')as f:
    index_table=json.load(f)
    print(len(index_table))
index_table
# Out:
# 9
# {'Royal': [{'name': 'Historia Regum Britanniae',
#    'page': 227,
#    'mss': '4. C. xi. ff. 222-249'},
#   {'name': "Turpin's Chronicle",
#    'page': 583,
#    'mss': '4. C. xi. ff. 280-286 b'},
#   {'name': 'Prophecy of Merlin Silvester',
#    'page': 313,
#    'mss': '5. F. xv. ff. 3 b'},
#   {'name': 'Dares Phrygius', 'page': 17, 'mss': '6. C. viii. ff. 123-133 b'},
#   {'name': 'Letters between Alexander and Dindimus',
#    'page': 138,
#    'mss': '6. E. iii. ff. 111 b-112 b'},
#   {'name': 'Letters between Alexander and Dindimus',
#    'page': 137,
#    'mss': '7. A. i. ff. 68 b-69 b'},
#   {'name': 'Alexandreis', 'page': 98, 'mss': '8. B. iv. ff. 19-71 b'},
#   {'name': 'Prophecies of Merlin',
#    'page': 297,
#    'mss': '8. D. iii. ff. 160 b-163'},
#   {'name': 'Guy of Warwick', 'page': 485, 'mss': '8. F. ix. ff. 105-159'},
#   {'name': 'Prophecy on Scotland', 'page': 327, 'mss': '9. B. ix. ff. 2'},
# ...

# %%
   
importlib.reload(combine_tables)
from utils import combine_tables
from utils.combine_tables import complie_index_table

index_table_clean=complie_index_table(index_table)

print(index_table_clean.keys())
with open("../results/vol1/vol1-index_table_clean.json","w", encoding='utf-8')as f:
    json.dump(index_table_clean, f, indent=2, ensure_ascii=False)
index_table_clean
# Out:
# dict_keys(['historia regum britanniae', "turpin's chronicle", 'prophecy of merlin silvester', 'dares phrygius', 'letters between alexander and dindimus', 'alexandreis', 'prophecies of merlin', 'guy of warwick', 'prophecy on scotland', 'alexander the great', 'prophecy', 'fulk fitz-warin', 'amya and amylion', 'tale of two lovers', 'historia trojana', 'story of troy', 'prophecy of the tenth sibyl', 'karolellus', 'roman de brut', 'havelok', 'vita merlini', 'prophecies of merlin silvester', 'historia regum britannia', 'apollonius of tyre', 'le chemin de vaillance', "livre de l'ordre de chevalerie", 'saint graal', 'lancelot du lac', 'perceforest', 'simon de pouille', 'aspremont', 'fierabras', 'ogier le danois', 'quatre fils aimon', 'pontus and sidoine', 'guy of warwick and heraud of ardennes', 'knight of the swan', 'iliaca', 'heroica', 'titus and vespasian', 'voyage of charlemagne to jerusalem and constantinople', 'sydrac and boctus', 'sir gowghter', 'tale of gamelyn', 'recueil des histoir
# ...

# %% [markdown]
# ### index+theme

# %%
import json
path_index_table_clean="../results/vol1/vol1-index_table_clean.json"
with open(path_index_table_clean,'r', encoding='utf-8') as f:
    index_table_clean=json.load(f)

path_theme_table_clean=r"../results/vol1/theme_table_clean.json"
with open(path_theme_table_clean,'r', encoding='utf-8') as f:
    theme_table_clean=json.load(f)

# %%
importlib.reload(combine_tables)
from utils.combine_tables import compile_combined_table
df_table=compile_combined_table(index_table_clean=index_table_clean, 
                                      theme_table=theme_table_clean)
# Out:
# [No match] title theme'latin poems' not found in table index!
# [No match] title theme'recueil' not found in table index!
# [No match] title theme'adam bell, and other ballads of forest life' not found in table index!
# [No match] title theme'voyage de charlemagne' not found in table index!
# [No match] title theme'chevalier au cygne' not found in table index!
# [No match] title theme'diana' not found in table index!
# [No match] title theme'siege of milan and sir otuel' not found in table index!
# ...

# %%
df_table
# df_table[df_table['mss'].isna()]
# df_table[["mss"]].value_counts(dropna=False)
# Out:
#                                      title_theme title_index  \
# 24                                   latin poems        None
# 45                                       recueil        None
# 255  adam bell, and other ballads of forest life        None
# 286                        voyage de charlemagne        None
# 306                           chevalier au cygne        None
# 329                                        diana        None
# 409                 siege of milan and sir otuel        None
#
#                                         author  \
# 24                      simon chèvre d'or, etc
# 45                              raoul le fèvre
# 255                                       None
# 286                                       None
# 306                                       None
# 329  jorge de montemayor (english translation)
# 409                                       None
#
#                               theme                 cycle collection mss_ff  \
# ...

# %%
df_table.to_csv("../results/vol1/vol1-combined_table.csv", index=False)

# %% [markdown]
# ### index + theme + notices

# %%
path_notices_clean=r"../results\vol1\vol1-notices_clean.json"
with open(path_notices_clean,'r', encoding='utf-8') as f:
    notices=json.load(f)
    print(notices)
notices
# Out:
# [{'notice': 'Vellxun; xvth cent. Small Qnarto; ff. 68, with 21 lines to a page. Headings, glosses, and initials, in red. Formerly belonged to Sir Bobert', 'mss': 'royal 16. c. zxiii. ff. 2-69 b.', 'material': 'vellxun', 'cent': 'xvth', 'size': 'small qnarto', 'mss_index': 'royal 16. c. xxiii. ff. 2-69 b', 'material_class': 'vellum', 'size_class': 'quarto', 'cent_i': 15}, {'notice': 'Paper ; t wo vols., a.d. 1560 and 1565. Small Quarto ; f f. 4 6, and ff. 98 ; t he full pages of Vol. i. h aving 35 to 36 and those of Vol. n. 24 to 27 lines of verse.', 'mss': 'royal 16* c. iv. a. b.', 'material': 'paper', 'cent': 't wo vols ad 1560 and 1565', 'size': 'small quarto', 'mss_index': 'royal 16. c. iv. a. b.', 'material_class': 'paper', 'size_class': 'quarto', 'cent_i': 16}, {'notice': 'Paper; zvith cent. ; t wo vol& Folio; ff. 160, and ff. 39; each full pago of Vol. I. ( A) having 21 to 25 lines of Greek, and 23 to 26 lines of Latin, and', 'mss': 'royal 16. d. iii. a. b.', 'material': 'paper
# ...

# %%
import pandas as pd
notices_df=pd.DataFrame(notices)
display(notices_df[['mss_index',"material_class","size_class", 'cent_i']])
# Out:
#                               mss_index material_class size_class  cent_i
# 0        royal 16. c. xxiii. ff. 2-69 b         vellum     quarto    15.0
# 1                royal 16. c. iv. a. b.          paper     quarto    16.0
# 2               royal 16. d. iii. a. b.          paper       None     6.0
# 3                 harley 5662. ff. 1-56          paper     quarto    15.0
# 4                additional add. 15,429          paper     octavo    15.0
# ..                                  ...            ...        ...     ...
# 400               additional add. 30864         vellum     quarto     5.0
# 401      additional add. 31042 ff 50-66          paper     quarto     NaN
# 402               additional add. 30864          paper     quarto     NaN
# 403  additional add. 31042 ff 125-163 b          paper     quarto    15.0
# 404            harley 4690. ff. 106-115         vellum      folio    15.0
#
# [405 rows x 4 columns]

# %%
df_all=df_table.merge(notices_df, on="mss_index", how='left')
display(df_all)
# Out:
#           title_theme                title_index                author  \
# 0             heroica                    heroica  flavius philostratus
# 1              iliaca                     iliaca       joannes tzetzes
# 2              iliaca                     iliaca       joannes tzetzes
# 3              iliaca                     iliaca       joannes tzetzes
# 4    dictys cretensis           dictys cretensis                  None
# ..                ...                        ...                   ...
# 617              None                 a propecye                  None
# 618              None       robin hood's garland                  None
# 619              None        ballads of scotland                  None
# 620              None   two charlemagne romances                  None
# 621              None  ipomedon and prothesilaus                  None
#
#                   theme          cycle  collection  \
# 0    classical romances  cycle of troy       royal
# ...

# %% [markdown]
# ## test:

# %%
index_table = {
  "Royal": [
    {"name": "Historia Regum Britanniae", "page": 227, "mss": "4. C. xi. ff. 222-249"},
    {"name": "Turpin's Chronicle", "page": 583, "mss": "4. C. xi. ff. 280-286 b"},
    {"name": "Prophecy of Merlin Silvester", "page": 313, "mss": "5. F. xv. ff. 3 b"},
    {"name": "Dares Phrygius", "page": 17, "mss": "6. C. viii. ff. 123-133 b"},
    {"name": "Letters between Alexander and Dindimus", "page": 138, "mss": "6. E. iii. ff. 111 b-112 b"},
    {"name": "Letters between Alexander and Dindimus", "page": 137, "mss": "7. A. i. ff. 68 b-69 b"},
    {"name": "Alexandreis", "page": 98, "mss": "8. B. iv. ff. 19-71 b"},
    {"name": "Prophecies of Merlin", "page": 297, "mss": "8. D. iii. ff. 160 b-163"},
    {"name": "Guy of Warwick", "page": 485, "mss": "8. F. ix. ff. 105-159"},
    {"name": "Prophecy on Scotland", "page": 327, "mss": "9. B. ix. ff. 2"},
    {"name": "Dares Phrygius", "page": 20, "mss": "10. A. x. ff. 188-192 b"},
    {"name": "Alexander the Great", "page": 112, "mss": "12. C. iv. ff. 138-170"},
    {"name": "Prophecy", "page": 316, "mss": "12. C. xii. ff. 14-16 b"},
    {"name": "Fulk Fitz-Warin", "page": 501, "mss": "12. C. xii. ff. 33-60 b"},
    {"name": "Amya and Amylion", "page": 674, "mss": "12. C. xii. ff. 69-76"},
    {"name": "Tale of Two Lovers", "page": 801, "mss": "12. C. xx. ff. 17-46"},
    {"name": "Historia Trojana", "page": 49, "mss": "12. D. iii. ff. 38-143"},
    {"name": "Story of Troy", "page": 34, "mss": "12. D. iii. ff. 152 b-158"},
    {"name": "Alexander the Great", "page": 106, "mss": "13. A. i."},
    {"name": "Historia Regum Britanniae", "page": 237, "mss": "13. A. iii. ff. 1-133"},
    {"name": "Prophecy of Merlin Silvester", "page": 315, "mss": "13. A. iii. ff. 135 b, 136"},
    {"name": "Story of Troy", "page": 27, "mss": "13. A. iv. ff. 22 b-23 b, 76-81 b"},
    {"name": "Alexander the Great", "page": 118, "mss": "13. A. v. ff. 2-23 b"},
    {"name": "Dares Phrygius", "page": 23, "mss": "13. A. v. ff. 88 b-98 b"},
    {"name": "Historia Regum Britanniae", "page": 237, "mss": "13. A. v. ff. 99-161 b"},
    {"name": "Prophecy of the Tenth Sibyl", "page": 194, "mss": "13. A. xiv. ff. 244-247"},
    {"name": "Karolellus", "page": 594, "mss": "13. A. xviii. ff. 136-149 b"},
    {"name": "Roman de Brut", "page": 264, "mss": "13. A. xxi. ff. 40 b-113"},
    {"name": "Havelok", "page": 423, "mss": "13. A. xxi. ff. 113-117 b"},
    {"name": "Havelok", "page": 940, "mss": "13. A. xxi. ff. 113-117 b"},
    {"name": "Historia Trojana", "page": 50, "mss": "13. C. xii. ff. 6-32 b"},
    {"name": "Alexander the Great", "page": 122, "mss": "13. C. xii. ff. 82-109 b"},
    {"name": "Historia Regum Britanniae", "page": 248, "mss": "13. D. i. ff. 175-212 b"},
    {"name": "Turpin's Chronicle", "page": 572, "mss": "13. D. i. ff. 212 b-222"},
    {"name": "Historia Regum Britanniae", "page": 228, "mss": "13. D. ii. ff. 124-173 b"},
    {"name": "Historia Regum Britanniae", "page": 229, "mss": "13. D. v. ff. 1-37 b"},
    {"name": "Vita Merlini", "page": 289, "mss": "13. E. i. ff. 143-146"},
    {"name": "Prophecies of Merlin Silvester", "page": 314, "mss": "13. E. ix. ff. 27"},
    {"name": "Historia Regum Britannia", "page": 238, "mss": "14. C. i. ff. 80-137"},
    {"name": "Apollonius of Tyre", "page": 170, "mss": "14. C. xi. ff. 80-83 b"},
    {"name": "Le Chemin de Vaillance", "page": 895, "mss": "14. E. ii. ff. 1-293"},
    {"name": "Livre de l'Ordre de Chevalerie", "page": 922, "mss": "14. E. ii. ff. 337-353 b"},
    {"name": "Saint Graal", "page": 341, "mss": "14. E. iii. ff. 3-88 b"},
    {"name": "Lancelot du Lac", "page": 354, "mss": "14. E. iii. ff. 89-161 b"},
    {"name": "Alexandreis", "page": 94, "mss": "15. A. x. ff. 2-89"},
    {"name": "Dares Phrygius", "page": 13, "mss": "15. A. xxii. ff. 73-90"},
    {"name": "Prophecy of the Tenth Sibyl", "page": 194, "mss": "15. A. xxii. ff. 110-115"},
    {"name": "Dares Phrygius", "page": 14, "mss": "15. B. xi. ff. 57-66 b"},
    {"name": "Prophecy of the Tenth Sibyl", "page": 193, "mss": "15. B. xi. ff. 67-69"},
    {"name": "Alexander the Great", "page": 110, "mss": "15. C. vi. ff. 102 b-130 b"},
    {"name": "Historia Trojana", "page": 44, "mss": "15. C. xvi. ff. 86-145"},
    {"name": "Historia Regum Britannia", "page": 239, "mss": "15. C. xvi. ff. 146-183 b"},
    {"name": "Prophecies of Merlin Silvester", "page": 313, "mss": "15. C. xvi. ff. 183 b, 184"},
    {"name": "Perceforest", "page": 377, "mss": "15. E. v."},
    {"name": "Alexander the Great", "page": 129, "mss": "15. E. vi. ff. 4 b-24 b"},
    {"name": "Simon de Pouille", "page": 627, "mss": "15. E. vi. ff. 25-42 b"},
    {"name": "Aspremont", "page": 598, "mss": "15. E. vi. ff. 43-69 b"},
    {"name": "Fierabras", "page": 615, "mss": "15. E. vi. ff. 70-85 b"},
    {"name": "Ogier le Danois", "page": 604, "mss": "15. E. vi. ff. 86-154 b"},
    {"name": "Quatre fils Aimon", "page": 622, "mss": "15. E. vi. ff. 155-206"},
    {"name": "Pontus and Sidoine", "page": 469, "mss": "15. E. vi. ff. 207-226 b"},
    {"name": "Guy of Warwick and Heraud of Ardennes", "page": 487, "mss": "15. E. vi. ff. 227-272"},
    {"name": "Knight of the Swan", "page": 708, "mss": "15. E. vi. ff. 273-292"},
    {"name": "Iliaca", "page": 2, "mss": "16. C. iv. A. B."},
    {"name": "Heroica", "page": 1, "mss": "16. C. xxiii. ff. 2-69 b"},
    {"name": "Iliaca", "page": 6, "mss": "16. D. iii. A. B."},
    {"name": "Titus and Vespasian", "page": 176, "mss": "16. E. viii. ff. 73-102 b"},
    {"name": "Voyage of Charlemagne to Jerusalem and Constantinople", "page": 625, "mss": "16. E. ff. 131-144 b"},
    {"name": "Sydrac and Boctus", "page": 914, "mss": "16. F. v. ff. 1-113 b"},
    {"name": "Historia Trojana", "page": 54, "mss": "16. F. ix."},
    {"name": "Quatre fils Aimon", "page": 619, "mss": "16. G. ii."},
    {"name": "Sir Gowghter", "page": 419, "mss": "17. B. xliii. ff. 116-131 b"},
    {"name": "Tale of Gamelyn", "page": 515, "mss": "17. D. xv. ff. 66 b-79 b"},
    {"name": "Recueil des Histoires de Troie", "page": 64, "mss": "17. E. ii."},
    {"name": "Mélusine", "page": 690, "mss": "18. B. ii."},
    {"name": "Tale of Gamelyn", "page": 514, "mss": "18. C. ii. ff. 56 b-67 b"},
    {"name": "Troy Book", "page": 81, "mss": "18. D. ii. ff. 6-146"},
    {"name": "Romance of Thebes", "page": 90, "mss": "18. D. ii. ff. 147 b-162"},
    {"name": "Troy Book", "page": 79, "mss": "18. D. vi."},
    {"name": "Roman de la Rose", "page": 885, "mss": "19. A. xviii."},
    {"name": "Lancelot du Lac", "page": 349, "mss": "19. B. vii."},
    {"name": "Roman de la Rose", "page": 888, "mss": "19. B. xii. ff. 2-147 b"},
    {"name": "Roman de la Rose", "page": 874, "mss": "19. B. xiii."},
    #{"name": "Lancelot du Lac", "page": 350, "mss": "19. D. i."},
    #{"name": "Morte Arthur", "page": 366, "mss": "19. D. ii."},
    #{"name": "Saint Graal", "page": 340, "mss": "19. D. iii."},
    #{"name": "Quest del Saint Graal", "page": 345, "mss": "19. D. iv."},
    #{"name": "Morte Arthur", "page": 363, "mss": "19. D. v."},
    #{"name": "Lancelot du Lac", "page": 351, "mss": "19. D. vi."},
    {"name": "Saint Graal", "page": 342, "mss": "19. C. vii."}, # pb un C. et pas un D.
    {"name": "Lancelot du Lac", "page": 345, "mss": "19. C. viii."},
    #{"name": "Morte Arthur", "page": 364, "mss": "19. D. ix."},
    #{"name": "Merlin", "page": 384, "mss": "19. D. x."},
#     {"name": "Roman de la Rose", "page": 886, "mss": "19. E. i."},
#     {"name": "Roman de la Rose", "page": 887, "mss": "19. E. ii."},
#     {"name": "Roman de la Rose", "page": 889, "mss": "19. E. iii."},
#     {"name": "Alexander the Great", "page": 108, "mss": "20. A. ii."},
#     {"name": "Letters between Alexander and Dindimus", "page": 188, "mss": "20. A. v. ff. 30-31 b"},
#     {"name": "Iliaca", "page": 3, "mss": "20. A. vi."},
#     {"name": "Iliaca", "page": 4, "mss": "20. A. x."},
#     {"name": "Iliaca", "page": 5, "mss": "20. A. xi."},
#     {"name": "Roman de la Rose", "page": 873, "mss": "20. B. i."},
#     {"name": "Roman de la Rose", "page": 876, "mss": "20. B. xi."},
#     {"name": "Roman de la Rose", "page": 874, "mss": "20. B. xii."}
#ajouts
    {"name": "Alexander the Great", "page": 123, "mss": "19. D. i. ff. 1-46"},
    {"name": "La Vengeance d'Alexandre", "page": 143, "mss": "19. D. i. ff. 47-57"},
    {"name": "Perceforest", "page": 377, "mss": "19. E. ii."},
    {"name": "Perceforest", "page": 377, "mss": "19. E. iii."},
    {"name": "Alexander the Great", "page": 125, "mss": "20. A. v."},
    {"name": "Roman de la Rose", "page": 880, "mss": "20. A. xvii."},
    {"name": "Lancelot du Lac", "page": 349, "mss": "20. B. xix."},
    {"name": "Guillaume d'Orange", "page": 654, "mss": "20. B. xix."},
    {"name": "Alexander the Great", "page": 128, "mss": "20. B. xx."},
    {"name": "Cleriadus et Meliadice", "page": 383, "mss": "20. C. ii. ff. 1-209 b"},
    {"name": "Apollonius of Tyre", "page": 166, "mss": "20. C. ii. ff. 210-236"},
    {"name": "Lancelot du Lac", "page": 350, "mss": "20. C. vi."},
    {"name": "Tristram", "page": 361, "mss": "20. D. ii."},
    {"name": "Lancelot du Lac", "page": 353, "mss": "20. D. iii."},
    {"name": "Lancelot du Lac", "page": 351, "mss": "20. D. iv."},
    {"name": "Roman de la Rose", "page": 889, "mss": "20. D. vii."},
    {"name": "Guillaume d'Orange", "page": 632, "mss": "20. D. xi."},
  ],
  "Cotton": [
    # il en manque une demi page
    {"name": "Prophecies of Merlin", "page": 299, "mss": "Julius A. v. ff. 5, 53-57b, 177 b-179, and 180-181 b"},  # faut-il rapprocher Prophecy of Merlin de Prophecies of Merlin?
    {"name": "Gesta Regum Britannia", "page": 274, "mss": "Julius D. xi. ff. 2-60"},  # pb le ae qui est mangé
    {"name": "Vita Merlini", "page": 289, "mss": "Julius E. viii. ff. 12 b-17 b"}, 
    {"name": "Troy Book", "page": 75, "mss": "Augustus A. iv."}, 
    {"name": "Prophecies of Merlin", "page": 295, "mss": "Tiberius A. ix. ff. 2-6"},
    {"name": "Sir Eglamour of Artois", "page": 766, "mss": "Caligula A. ii. ff. 5 b-13"}, 
    {"name": "Octavian the Emperor", "page": 762, "mss": "Caligula A. ii. ff. 22 b-35"}, 
    {"name": "Sir Launfal", "page": 416, "mss": "Caligula A. ii. ff. 35 b-42 b"}, 
    {"name": "Lybeaus Desconus", "page": 400, "mss": "Caligula A. ii. ff. 42 b-57"}, 
    {"name": "Emare", "page": 418, "mss": "Caligula A. ii. ff. 71-76 b"}, 
    {"name": "Titus and Vespasian", "page": 180, "mss": "Caligula A. ii. ff. 111-125"}, 
    {"name": "Knight of the Swan", "page": 710, "mss": "Caligula A. ii. ff. 125 b-129 b"}, 
    {"name": "Sir Isumbras", "page": 760, "mss": "Caligula A. ii. ff. 130-134"}, 
    {"name": "Lazamon's Brut", "page": 268, "mss": "Caligula A. ix. ff. 3-194 b"}, 
    {"name": "Prophecy of the Tenth Sibyl", "page": 195, "mss": "Caligula A. x. ff. 200-204"}, 
    {"name": "Turpin's Chronicle", "page": 561, "mss": "Caligula B. vii. ff. 192-203 b"}, 
    {"name": "Prophecy of Merlin", "page": 303, "mss": "Caligula B. vii. ff. 210-213"},
    {"name": "Dares Phrygius", "page": 22, "mss": "Caligula B. vii. ff. 214-218 b"}, 
    {"name": "Prophecy of the Tenth Sibyl", "page": 193, "mss": "Caligula B. vii. ff. 219, 220"},
    {"name": "Prophecies of Merlin", "page": 296, "mss": "Caligula B. vii. ff. 220 b-231 b"},
    {"name": "Prophecies", "page": 317, "mss": "Claudius E. viii. ff. 1 b, 23"},
    {"name": "Prophecies of Merlin", "page": 297, "mss": "Nero A. iv. ff. 63-76 b"},
    {"name": "Sir Gawain and the Green Knight", "page": 387, "mss": "Nero A. x. ff. 90 b-126"}, 
    {"name": "Turpin's Chronicle", "page": 546, "mss": "Nero A. xi. ff. 8-63"},
    {"name": "Turpin's Chronicle", "page": 950, "mss": "Nero A. xi. ff. 8-63"},


    {"name": "Historia Regum Britanniae", "page": 230, "mss": "Nero D. viii. ff. 3-63"},
    {"name": "Alexander the Great", "page": 113, "mss": "Nero D. viii. ff. 160-174 b"},
    {"name": "Story of Albina and her Sisters", "page": 199, "mss": "Nero D. viii. ff. 186, 187"},
    {"name": "Petit Jean de Saintré", "page": 775, "mss": "Nero D. ix. ff. 1-108"},
    {"name": "Floridam and Elluide", "page": 779, "mss": "Nero D. ix. ff. 109-115"},
    {"name": "Ywain and Gawain", "page": 392, "mss": "Galba E. ix. ff. 4-25"},
    {"name": "Merlin's Prophecy of the Six Kings", "page": 309, "mss": "Galba E. ix. ff. 49, 50"},
    {"name": "Historia Regum Britanniae", "page": 239, "mss": "Galba E. xi. ff. 2-58 b"},
    {"name": "Letters of Dindimus to Alexander the Great", "page": 136, "mss": "Galba E. xi. ff. 98 b-101 b"},
    {"name": "Alexander the Great", "page": 115, "mss": "Galba E. xi. ff. 111-125"},
    {"name": "Lisamon's Brut", "page": 271, "mss": "Otho C. xiii."},
    {"name": "Roman de Brut", "page": 259, "mss": "Vitellius A. x. ff. 19-114 b"},
    {"name": "Dares Phrygius", "page": 15, "mss": "Vitellius A. xiii. ff. 90"},
    {"name": "Marvels of India", "page": 134, "mss": "Vitellius A. xv. ff. 109-133 b"},
    {"name": "Dares Phrygius", "page": 18, "mss": "Vitellius C. viii. ff. 5 b-6 b"},
    {"name": "Floyras and Blanchefleur", "page": 716, "mss": "Vitellius D. iii. ff. 6-8 b"},
    {"name": "Thomas of Erceldoune", "page": 330, "mss": "Vitellius E. x. ff. 240 b-243"},
    {"name": "Ipomodon", "page": 728, "mss": "Vespasian A. vii. ff. 37-104"},
    {"name": "Brutus", "page": 277, "mss": "Vespasian A. x. ff. 44 b-51"},
    {"name": "Turpin's Chronicle", "page": 576, "mss": "Vespasian A. xiii. ff. 94-114 b"},
    {"name": "Apollonius of Tyre", "page": 164, "mss": "Vespasian A. xiii. ff. 132-147 b"},
    {"name": "Historia Regum Britanniae", "page": 241, "mss": "Vespasian A. xxiii. ff. 4-106 b"},
    {"name": "Lanval", "page": 415, "mss": "Vespasian B. xiv. ff. 1-8 b"},
    {"name": "Fall of Troy", "page": 31, "mss": "Vespasian B. xiv. ff. 18, 18 b"},
    {"name": "Fall of Troy and Adventures of Æneas", "page": 33, "mss": "Vespasian B. xxiii. Part III. ff. 118 b-122 b"},
    {"name": "Dares Phrygius", "page": 12, "mss": "Vespasian B. xxv. ff. 98 b-117"},
    {"name": "Prophecy of the Tenth Sibyl", "page": 192, "mss": "Vespasian B. xxv. ff. 117 b-123"},
    {"name": "Guy of Warwick", "page": 492, "mss": "Vespasian D. ix. ff. 40-43 b"},
    {"name": "Two Prophecies", "page": 325, "mss": "Vespasian D. xviii. ff. 125 b-127* b"},
    {"name": "Vita Merlini", "page": 278, "mss": "Vespasian E. iv. ff. 112 b-138 b"},
    {"name": "Prophecy of the Tenth Sibyl", "page": 194, "mss": "Vespasian E. iv. ff. 143-147"},
    {"name": "Prophecies of Merlin, etc.", "page": 320, "mss": "Vespasian E. vii. ff. 78-126, 129, 130"},
    {"name": "Whole Prophecy of Scotland", "page": 337, "mss": "Vespasian E. viii. ff. 16-29"},
    {"name": "Historia Regum Britanniae", "page": 242, "mss": "Vespasian E. x. ff. 271-368 b"},
    {"name": "Story of Albina and her Sisters", "page": 200, "mss": "Vespasian E. x. ff. 390 b-392"},
    {"name": "Titus and Vespasian", "page": 185, "mss": "Vespasian E. xvi. ff. 70-75 b"},
    {"name": "Historia Regum Britanniae", "page": 243, "mss": "Titus A. xviii. ff. 13-82"},
    {"name": "Turpin's Chronicle", "page": 578, "mss": "Titus A. xix. ff. 24-43"},
    {"name": "Vita Merlini", "page": 290, "mss": "Titus A. xix. ff. 63-73 b"},
    {"name": "Story of Albina and her Sisters", "page": 201, "mss": "Titus A. xix. ff. 103"},
    {"name": "Battle of Roncevaux", "page": 630, "mss": "Titus A. xix. ff. 153-155"},
    {"name": "Story of Troy and Adventures of Æneas", "page": 29, "mss": "Titus A. xx. ff. 99-104"},
    {"name": "Historia Regum Britanniae", "page": 244, "mss": "Titus A. xxv. ff. 105-116 b"},
    {"name": "Historia Regum Britanniae", "page": 231, "mss": "Titus A. xxvii. ff. 1 b-87"},
    {"name": "Historia Regum Britanniae", "page": 203, "mss": "Titus C. xvii."},
    {"name": "Apollonius of Tyre", "page": 169, "mss": "Titus D. iii. ff. 127-137 b"},
    {"name": "Prophecy of the Tenth Sibyl", "page": 191, "mss": "Titus D. iii. ff. 143-147 b"},
    {"name": "Prophecy of Merlin", "page": 301, "mss": "Titus D. vii. ff. 26-36"},
    {"name": "Prophecies", "page": 319, "mss": "Titus D. xix. ff. 118"},
    {"name": "Prophecy of the Tenth Sibyl", "page": 193, "mss": "Domitian xiii. ff. 104-107"},
    {"name": "Prophecy of the Tenth Sibyl", "page": 195, "mss": "Domitian xiii. ff. 132 b-134 b"},

    {"name": "Fall of Troy", "page": 30, "mss": "Cleopatra A. viii. ff. 56-58"},
    {"name": "Brut y Brenhinoedd", "page": 255, "mss": "Cleopatra B. v. ff. 1-108 b"},
    {"name": "Dares Phrygius", "page": 26, "mss": "Cleopatra B. v. ff. 222-250"},
    {"name": "Prophecies of Merlin", "page": 310, "mss": "Cleopatra C. iv. ff. 74-122"},
    
    # aie.... plein de changements ici
    
    {"name": "Prophecy of Merlin", "page": 298, "mss": "Cleopatra C. iv. ff. 55 b and 66-68 b"},
    #{"name": "Prophecy of the Lily, the Lion, and the Son of Man", "page": 318, "mss": "Cleopatra D. iii. f. 184"},
    {"name": "Prophecy of the Lily, the Lion, and the Son of Man", "page": 318, "mss": "Cleopatra D. iii. ff. 184"},
    {"name": "Alexander the Great", "page": 114, "mss": "Cleopatra D. v. ff. 165 b-183"},
    {"name": "Story of Albina and her Sisters", "page": 200, "mss": "Cleopatra D. viii. ff. 3 b-5"},
    {"name": "Historia Regum Britanniae", "page": 249, "mss": "Cleopatra D. viii. ff. 8-94"},
    {"name": "Story of Albina and her Sisters", "page": 198, "mss": "Cleopatra D. ix. ff. 67, 68"},
    {"name": "Prophecies of Merlin", "page": 292, "mss": "Faustina A. viii. ff. 109 b-116"},
    {"name": "Meriadoc and Gawain", "page": 374, "mss": "Faustina B. vi. ff. 2-40 b"},
    {"name": "Prophecies", "page": 319, "mss": "Faustina B. ix. ff. 241 b, 242"},
    {"name": "Prophecies of Merlin Silvester", "page": 315, "mss": "Cotton Appendix iv. ff. 102 b"},
    {"name": "Romance of Thebes", "page": 91, "mss": "Cotton Appendix xxvii. ff. 11-61; formerly ff. 106-130 b, and xxxix. ff. 80-103 b"},
    {"name": "Four Prophecies", "page": 324, "mss": "Cotton Roll ii. 23"}
  ],
  "Harley": [
    {"name": "Tristram", "page": 358, "mss": "Harley 49"},
    {"name": "Historia Trojana", "page": 52, "mss": "Harley 51. ff. 3-105 b"},
    {"name": "Turpin's Chronicle", "page": 574, "mss": "Harley 108. ff. 4 b-31 b"},
    {"name": "Historia Trojana", "page": 47, "mss": "Harley 176"},
    {"name": "Historia Regum Britanniae", "page": 222, "mss": "Harley 225. ff. 3-78"},
    {"name": "Turpin's Chronicle", "page": 587, "mss": "Harley 273. ff. 86-102 b"},
    {"name": "The Three Kings' Sons", "page": 782, "mss": "Harley 326. ff. 8-123 b"},
    {"name": "Romance of Troy", "page": 84, "mss": "Harley 525. ff. 1-34 b"},
    {"name": "King Robert of Sicily", "page": 765, "mss": "Harley 525. ff. 35-43 b"},
    {"name": "Gui de Bourgogne", "page": 630, "mss": "Harley 527. ff. 1-32"},
    {"name": "Alexander the Great", "page": 113, "mss": "Harley 527. ff. 47-56 b"},
    {"name": "King Horn", "page": 468, "mss": "Harley 527. ff. 59-73 b"},
    {"name": "Historia Regum Britanniae", "page": 226, "mss": "Harley 536. ff. 58-61"},
    {"name": "Political Prophecies", "page": 326, "mss": "Harley 559. ff. 1-13, 31-35, 39-48"},
    {"name": "Dares Phrygius", "page": 20, "mss": "Harley 641. ff. 1-8"},
    {"name": "Vita Merlini", "page": 288, "mss": "Harley 655. ff. 200 b-204 b"},
    {"name": "Merlin's Prophecy of the Six Kings", "page": 309, "mss": "Harley 746. ff. 1 b-3"},
    
    {"name": "Prophecy of Merlin", "page": 302, "mss": "Harley 838. ff. 92-93 b"},
    {"name": "Story of Albina and her Sisters", "page": 201, "mss": "Harley 941. ff. 1-3"},
    {"name": "Lays of Marie de France", "page": 407, "mss": "Harley 978. ff. 118-160"},
    {"name": "Prophecy of the Lily, the Lion, and the Son of Man", "page": 318, "mss": "Harley 1008. ff. 81"},
    {"name": "Sydrac and Boctus", "page": 912, "mss": "Harley 1121. ff. 1-140"},
    {"name": "Troilus and Cryseyde", "page": 73, "mss": "Harley 1239. ff. 1-62 b"},
    {"name": "Guillaume d'Orange", "page": 660, "mss": "Harley 1321"},
    {"name": "Chanson de Brut", "page": 272, "mss": "Harley 1605. Art. I."},
    {"name": "Prophecies de Merlin", "page": 373, "mss": "Harley 1629"},
    {"name": "King Robert of Sicily", "page": 765, "mss": "Harley 1701. ff. 92-95"},
    {"name": "Prophecies of Merlin and others", "page": 312, "mss": "Harley 1717. ff. 249 b-250 b"},
    {"name": "Tale of Gamelyn", "page": 513, "mss": "Harley 1758. ff. 48-55"},
    {"name": "Tale of Two Lovers", "page": 799, "mss": "Harley 1883. ff. 119-135 b"},
    {"name": "Ipomedon", "page": 755, "mss": "Harley 2252. ff. 54-84"},
    {"name": "Morte Arthur", "page": 405, "mss": "Harley 2252. ff. 86-133 b"},
    {"name": "Six Fabliaux", "page": 813, "mss": "Harley 2253. ff. 67 b, 107 b, 110, 115 b, 118, 122 b"},
    {"name": "King Horn", "page": 447, "mss": "Harley 2253. ff. 83-92 b"},
    {"name": "Prophecy of Thomas of Erceldoune", "page": 328, "mss": "Harley 2253. ff. 127, col. 2"},
    {"name": "Troilus and Cryseyde", "page": 70, "mss": "Harley 2280"},
    {"name": "Turpin's Chronicle", "page": 582, "mss": "Harley 2361. ff. 138-139 b"},
    {"name": "Story of Albina and her Sisters", "page": 202, "mss": "Harley 2386. ff. 65 b-67"},
    {"name": "Amys and Amylion", "page": 677, "mss": "Harley 2386. ff. 131-138"},
    {"name": "Troilus and Cryseyde", "page": 73, "mss": "Harley 2392"},
    {"name": "Letter of Dindimus to Alexander the Great", "page": 139, "mss": "Harley 2488. ff. 114-117 b"},
    {"name": "Tale of Two Lovers", "page": 802, "mss": "Harley 2492. ff. 154 b-169 b"},
    {"name": "Turpin's Chronicle", "page": 581, "mss": "Harley 2500. ff. 139-155"},
    {"name": "Aronus and Marina", "page": 797, "mss": "Harley 2678. ff. 93-96 b"},
    {"name": "Alexander the Great", "page": 109, "mss": "Harley 2682. ff. 180-192"},
    {"name": "Turpin's Chronicle", "page": 577, "mss": "Harley 3043. ff. 17-31"},
    {"name": "Fall of Troy", "page": 32, "mss": "Harley 3202. ff. 114 b-115 b"},
    {"name": "Filocolo", "page": 725, "mss": "Harley 3314"},
    {"name": "Dictys Cretensis", "page": 11, "mss": "Harley 3514"},
    {"name": "Corbaccio", "page": 794, "mss": "Harley 3581"},
    {"name": "Fiammetta", "page": 793, "mss": "Harley 3573"},
    {"name": "Historia Trojana", "page": 48, "mss": "Harley 3637"},
    {"name": "Historia Trojana", "page": 54, "mss": "Harley 3681"},
    {"name": "Historia Regum Britanniae", "page": 223, "mss": "Harley 3773. ff. 7-57"},
    {"name": "Guy of Warwick", "page": 471, "mss": "Harley 3775. ff. 15-26 b"},
    {"name": "Life of Harold, King of England", "page": 941, "mss": "Harley 3776. ff. 1-24 b"},
    {"name": "Sir Orpheo", "page": 171, "mss": "Harley 3810. Part I. ff. 1-10"},
    {"name": "Tale of Antiochus", "page": 798, "mss": "Harley 3830. ff. 11 b-17 b"},
    {"name": "Troilus and Cryseyde", "page": 72, "mss": "Harley 3943"},
    {"name": "Florimont", "page": 159, "mss": "Harley 3983. ff. 2-82 b"},
    {"name": "Voeux du Paon", "page": 154, "mss": "Harley 3992"},
    {"name": "Historia Regum Britanniae", "page": 244, "mss": "Harley 4003. ff. 81-141 b"},
    {"name": "Historia Regum Britanniae", "page": 236, "mss": "Harley 4123. ff. 2-49 b"},
    {"name": "Historia Trojana", "page": 40, "mss": "Harley 4123. ff. 50-126"},
    {"name": "Sydrac and Boctus", "page": 918, "mss": "Harley 4294. ff. 1-79 b"},
    {"name": "L'Ordène de Chevalerie", "page": 810, "mss": "Harley 4333. ff. 115-117 b"},
    {"name": "Girard de Roussillon", "page": 663, "mss": "Harley 4334"},
    {"name": "Sydrac and Boctus", "page": 911, "mss": "Harley 4361"},
    {"name": "Historia Trojana", "page": 53, "mss": "Harley 4387"},
    {"name": "Tristram", "page": 356, "mss": "Harley 4389"},
    {"name": "Doon de la Roche", "page": 671, "mss": "Harley 4404. ff. 1-98"},
    {"name": "Enfances Ogier", "page": 610, "mss": "Harley 4404. ff. 102-251 b"},
    {"name": "Sydrac and Boctus", "page": 908, "mss": "Harley 4417. ff. 1-141 b"},
    {"name": "Mélusine", "page": 687, "mss": "Harley 4418"},
    {"name": "Lancelot du Lac", "page": 353, "mss": "Harley 4419"},
    {"name": "Roman de la Rose", "page": 892, "mss": "Harley 4425"},
    {"name": "Roman de Troie", "page": 35, "mss": "Harley 4482"},
    {"name": "Sydrac and Boctus", "page": 913, "mss": "Harley 4486. ff. 69-146"},
    {"name": "Florimont", "page": 156, "mss": "Harley 4487. ff. 3-96"},
    {"name": "Richard Cœur-de-Lion", "page": 949, "mss": "Harley 4690. ff. 106-115"},
    {"name": "Alexandreis", "page": 103, "mss": "Harley 4745"},
    {"name": "Troilus and Cryseyde", "page": 74, "mss": "Harley 4912"},
    {"name": "Alexander the Great", "page": 127, "mss": "Harley 4979"},
    {"name": "Alexander the Great", "page": 119, "mss": "Harley 5054. ff. 124 b-181"},
    {"name": "Historia Regum Britanniae", "page": 245, "mss": "Harley 5115. ff. 87-150"},
    {"name": "Guy of Warwick", "page": 497, "mss": "Harley 5243"},
    {"name": "Fiammetta", "page": 792, "mss": "Harley 5427"},
    {"name": "Alexandreis", "page": 103, "mss": "Harley 5437"},
    {"name": "Iliaca", "page": 8, "mss": "Harley 5662. ff. 1-56"},
    {"name": "Prophecies taken from Geoffrey of Monmouth and others", "page": 311, "mss": "Harley 6148. ff. 86-98 b"},
    {"name": "Merlin", "page": 385, "mss": "Harley 6223. Art. I."},
    {"name": "Merlin", "page": 344, "mss": "Harley 6340"},
    {"name": "Lancelot du Lac", "page": 355, "mss": "Harley 6341"},
    {"name": "Historia Regum Britanniae", "page": 235, "mss": "Harley 6358. ff. 2-58 b"},
    {"name": "Turpin's Chronicle", "page": 560, "mss": "Harley 6358. ff. 60-83"},
    {"name": "Roman de Brut", "page": 263, "mss": "Harley 6508"},
    {"name": "Theagenes and Stelliana", "page": 795, "mss": "Harley 6758"},
    {"name": "Guy of Warwick", "page": 494, "mss": "Harley 7333. ff. 33-35 b"},
    {"name": "Tale of Gamelyn", "page": 508, "mss": "Harley 7334. ff. 59-70 b"}
  ],
  "Lansdowne": [
    {"name": "Kings of Britain", "page": 251, "mss": "Lansdowne 214. ff. 85-193"}, 
    {"name": "Historia Trojana", "page": 61, "mss": "Lansdowne 229. ff. 164"}, 
    {"name": "Florence de Rome", "page": 711, "mss": "Lansdowne 362. ff. 75*, 75**, 76, 77"}, 
    {"name": "Abridgement of Historia Trojana", "page": 59, "mss": "Lansdowne 380. ff. 36-39 b"}, 
    {"name": "Chanson de Roland", "page": 631, "mss": "Lansdowne 388. ff. 381-395 b"}, 
    {"name": "Guy of Warwick", "page": 496, "mss": "Lansdowne 699. ff. 18 b-27 b"}, 

    #{"name": "Historia Regum Britanniae", "page": 233, "mss": "214. ff. 85-193"},
    #{"name": "Lancelot du Lac", "page": 347, "mss": "229. f. 164"},
    #{"name": "Historia Trojana", "page": 61, "mss": "362. ff. 75*, 75**"},
    #{"name": "Florence de Rome", "page": 711, "mss": "76, 77"},
    #{"name": "Abridgement of Historia Trojana", "page": 59, "mss": "380. ff. 36-39 b"},
    #{"name": "Chanson de Roland", "page": 631, "mss": "388. ff. 381-395 b"},
    #{"name": "Guy of Warwick", "page": 496, "mss": "699. ff. 18 b-27 b"},
    {"name": "Historia Regum Britanniae", "page": 233, "mss": "Lansdowne 732. ff. 1-68 b"},
    {"name": "Lancelot du Lac", "page": 347, "mss": "Lansdowne 757"},
    {"name": "Thomas of Erceldoune", "page": 331, "mss": "Lansdowne 762. ff. 24-31, 48-58 b, 61 b-71, 75-88"},
    {"name": "Amadis de Gaula", "page": 787, "mss": "Lansdowne 766. ff. 1-18 b"},
    {"name": "Chanson d'Aspremont", "page": 600, "mss": "Lansdowne 782"},
    {"name": "Sydrac and Boctus", "page": 915, "mss": "Lansdowne 793"},
    {"name": "Tale of Gamelyn", "page": 512, "mss": "Lansdowne 851. ff. 54 b-65"}
  ],
  "Arundel": [
    {"name": "Historia Trojana", "page": 60, "mss": "Arundel 6 ff. 242-342 b"},
    {"name": "Historia Regum Britanniae", "page": 224, "mss": "Arundel 10"},
    {"name": "Prophecies of Merlin, Gildas, and Thomas of Ercildoune", "page": 307, "mss": "Arundel 57. ff. 4 b-11"},
    {"name": "Prophecies of Merlin", "page": 301, "mss": "Arundel 66. ff. 267-268 b and 291 b"},
    {"name": "Troy Book", "page": 80, "mss": "Arundel 99"},
    {"name": "Romance of Thebes", "page": 87, "mss": "Arundel 119"},
    {"name": "Apollonius of Tyre", "page": 164, "mss": "Arundel 123. ff. 33-42 b"},
    {"name": "Alexander the Great", "page": 120, "mss": "Arundel 123. ff. 43-71"},
    {"name": "Letter of Dindimus to Alexander the Great", "page": 140, "mss": "Arundel 138. ff. 126, 126 b"},
    {"name": "Historia Trojana", "page": 51, "mss": "Arundel 174"},
    {"name": "Birth of Merlin", "page": 384, "mss": "Arundel 220. Art. L"},
    {"name": "Turpin's Chronicle", "page": 589, "mss": "Arundel 220. ff. 284-298 b"},
    {"name": "Voeux du Paon", "page": 155, "mss": "Arundel 230 ff. 181 b"},
    {"name": "Historia Regum Britanniae", "page": 241, "mss": "Arundel 237"},
    {"name": "Marvels of India", "page": 133, "mss": "Arundel 242. ff. 160-182"},
    {"name": "Apollonius of Tyre", "page": 163, "mss": "Arundel 292. ff. 41-61"},
    {"name": "Historia Regum Britanniae", "page": 232, "mss": "Arundel 319. ff. 16-97 b"},
    {"name": "Historia Regum Britanniae", "page": 246, "mss": "Arundel 326. ff. 63-122 b"},
    {"name": "Historia Regum Britanniae", "page": 225, "mss": "Arundel 403"},
    {"name": "Historia Regum Britanniae", "page": 233, "mss": "Arundel 409. ff. 54-77"},
    {"name": "Treatise on the Brahmins", "page": 134, "mss": "Arundel 546. ff. 265 b-280 b"}
  ],
  "Burney": [
    {"name": "Dictys Cretensis", "page": 9, "mss": "Burney 170"},
    {"name": "History of Troy", "page": 66, "mss": "Burney 186. ff. 116-128"},
    {"name": "Dares Phrygius", "page": 16, "mss": "Burney 216. ff. 89-93 b"},
    {"name": "Alexander the Great", "page": 118, "mss": "Burney 280. ff. 1-20 b"},
    {"name": "Dares Phrygius", "page": 21, "mss": "Burney 280. ff. 20 b-38 b"},
    {"name": "Alexandreis", "page": 101, "mss": "Burney 312"}
  ],
  "Sloane": [
    {"name": "Historia Regum Britanniae", "page": 250, "mss": "Sloane 289. ff. 120-133"},
    {"name": "Cassandra", "page": 803, "mss": "Sloane 457"},
    {"name": "Life of Robin Hood", "page": 517, "mss": "Sloane 780. ff. 46-48 b"},
    {"name": "Quatre fils Aimon", "page": 624, "mss": "Sloane 960"},
    {"name": "Guy of Warwick", "page": 489, "mss": "Sloane 1044. ff. 625"},
    {"name": "Alexander the Great", "page": 112, "mss": "Sloane 1619. ff. 3-17 b"},
    {"name": "Apollonius of Tyre", "page": 161, "mss": "Sloane 1619 ff. 18-29"},
    {"name": "Dares Phrygius", "page": 19, "mss": "Sloane 1619 ff. 29-37 b"},
    {"name": "Tale of Gamelyn", "page": 514, "mss": "Sloane 1685. ff. 51 b-62 b"},
    {"name": "Tale of Gamelyn", "page": 515, "mss": "Sloane 1686. ff. 71-86 b"},
    {"name": "Alexander the Great", "page": 131, "mss": "Sloane 1785. ff. 2-13"},
    {"name": "Whole Prophecy of Scotland", "page": 334, "mss": "Sloane 1802"},
    {"name": "Sydrac and Boctus", "page": 919, "mss": "Sloane 2232"},
    {"name": "Apollonius of Tyre", "page": 165, "mss": "Sloane 2233"},
    {"name": "Collection of Prophecies", "page": 333, "mss": "Sloane 2578"},
    {"name": "Robyn and Gandelyn", "page": 516, "mss": "Sloane 2593. ff. 14 b-15 b"},
    {"name": "Letter of Dindimus to Alexander the Great", "page": 140, "mss": "Sloane 3991. ff. 95-97"}
  ],
  "Additional": [
    {"name": "Apollonius of Tyre", "page": 167, "mss": "Add. 4857. ff. 28-56 b"},
    {"name": "Five Romantic Tales", "page": 841, "mss": "Add. 4857. ff. 89, 97 b, 110, 134, 139 b"},
    {"name": "Ívents saga", "page": 393, "mss": "Add. 4857. ff. 113 b-133 b"},
    {"name": "Eight Romantic Tales", "page": 843, "mss": "Add. 4859. ff. 10, 15, 142 b, 240, 313, 314, 344 b, 367"},
    {"name": "Ívents saga", "page": 393, "mss": "Add. 4857. ff. 32-45 b"},
    
    {"name": "Eight Romantic Tales", "page": 843, "mss": "Add. 4859. ff. 10, 15, 142 b, 240, 813, 314, 344 b, 367"},
    {"name": "Ívents saga", "page": 394, "mss": "Add. 4859. ff. 32-45 b"},

    {"name": "Parcevals saga and Valvers þáttr", "page": 395, "mss": "Add. 4859. ff. 46-65 b"},
    {"name": "Ereks saga Artuskappa", "page": 403, "mss": "Add. 4859. ff. 66-74 b"},
    {"name": "Möttuls saga", "page": 405, "mss": "Add. 4859. ff. 75-81"},
    {"name": "Life of Virgilius", "page": 196, "mss": "Add. 4859. ff. 81 b-91"},
    {"name": "Eight Romantic Tales", "page": 846, "mss": "Add. 4860. ff. 1, 17, 29, 95, 273, 285, 293, 329"},
    {"name": "Magus saga Jarls", "page": 686, "mss": "Add. 4860. ff. 157-188 b"},
    {"name": "Partalópa saga", "page": 707, "mss": "Add. 4860. ff. 189-206"},
    {"name": "Seven Romantic Tales", "page": 847, "mss": "Add. 4863. ff. 25, 69, 119, 153, 181, 189, 229"},
    {"name": "Samsons saga Fagra", "page": 407, "mss": "Add. 4863. ff. 47-68 b"},
    {"name": "Apollonius of Tyre", "page": 168, "mss": "Add. 4864. ff. 88-114 b"},
    {"name": "Trójumanna saga", "page": 62, "mss": "Add. 4869. ff. 2-66"},
    {"name": "Magus saga Jarls", "page": 684, "mss": "Add. 4869. ff. 67-101 b"},
    {"name": "Two Romantic Tales", "page": 850, "mss": "Add. 4869. ff. 161, 206"},
    {"name": "Three Romantic Tales", "page": 851, "mss": "Add. 4870. ff. 62, 69, 83 b"},
    {"name": "Magus saga Jarls", "page": 688, "mss": "Add. 4874. ff. 1-66"},
    {"name": "Three Romantic Tales", "page": 852, "mss": "Add. 4874. ff. 98 b, 110, 138"},
    {"name": "Three Romantic Tales", "page": 854, "mss": "Add. 4875. ff. 1, 25 b, 54 b"},
    {"name": "Saga of Ajax Frækni", "page": 854, "mss": "Add. 4884. ff. 167-178"},
    {"name": "Tristram", "page": 359, "mss": "Add. 5474"},
    {"name": "Merlínus Spá", "page": 304, "mss": "Add. 6121. ff. 55-71"},
    # jusque là c'est ok fin page 9

    # mange la page 10
    {"name": "Mélusine", "page": 692, "mss": "Add. 6796"},
    {"name": "Prophecies of Merlin", "page": 304, "mss": "Add. 6924. ff. 73-124 and 164-"},
    {"name": "Turpin's Chronicle", "page": 583, "mss": "Add. 6924. ff. 297-303"},
    {"name": "Historia Trojana", "page": 57, "mss": "Add. 9785"},
    {"name": "Titus and Vespasian", "page": 187, "mss": "Add. 10,038. ff. 2-81 b"},
    {"name": "Dares Phrygius", "page": 24, "mss": "Add. 10,094. ff. 1-14 b"},
    {"name": "Sydrac and Boctus", "page": 921, "mss": "Add. 10,286. ff. 2-114"},
    {"name": "Titus and Vespasian", "page": 179, "mss": "Add. 10,289. ff. 82-121"},
    {"name": "Juglet", "page": 812, "mss": "Add. 10,289. ff. 175 b-178 b"},
    {"name": "Romance of Jason", "page": 92, "mss": "Add. 10,290. ff. 2-161"},
    {"name": "Saint Graal", "page": 340, "mss": "Add. 10,292. ff. 1-76"},
    {"name": "Merlin", "page": 343, "mss": "Add. 10,292. ff. 76-216 b"},
    {"name": "Lancelot du Lac", "page": 352, "mss": "Add. 10,293"},
    {"name": "Lancelot du Lac", "page": 352, "mss": "Add. 10,294"},
    {"name": "Artus de Bretagne", "page": 382, "mss": "Add. 10,295"},
    {"name": "Fioccolo", "page": 724, "mss": "Add. 10,296"},
    {"name": "Riccardetto", "page": 680, "mss": "Add. 10,321"},
    {"name": "Aspremont", "page": 602, "mss": "Add. 10,508. ff. 1-63 b"},
    {"name": "Romance of the Peers of France", "page": 682, "mss": "Add. 10,508. ff. 64-96 b"},
    {"name": "Rimur of Remund", "page": 855, "mss": "Add. 11,110. ff. 101-144"},
    {"name": "Rimur from Trójumanna saga", "page": 63, "mss": "Add. 11,113. ff. 171-281"},
    {"name": "Life of Virgilius", "page": 197, "mss": "Add. 11,141. ff. 132-147"},
    {"name": "Collection of Anecdotes", "page": 865, "mss": "Add. 11,153. ff. 182-263"},
    {"name": "Gabons saga ok Vigolea", "page": 402, "mss": "Add. 11,157. ff. 1-46 b"},
    {"name": "Valentine and Orson and Tales", "page": 857, "mss": "Add. 11,157. ff. 90, 176, 188"},
    {"name": "Ten Romantic Tales", "page": 858, "mss": "Add. 11,158. ff. 1, 24, 83, 71, 123, 201, 233, 251, 261 b, 268, 289"},
    {"name": "Patient Griselda", "page": 865, "mss": "Add. 11,163. ff. 120 b-136 b"},
    {"name": "Argenis", "page": 866, "mss": "Add. 11,164"},
    {"name": "Merlinus Spá", "page": 307, "mss": "Add. 11,174. ff. 85-98"},
    {"name": "Alexander saga", "page": 104, "mss": "Add. 11,238. ff. 507-692 b"},
    {"name": "Two Romantic Tales", "page": 867, "mss": "Add. 11,241. ff. 95, 140"},
    {"name": "Petit Jean de Saintré", "page": 778, "mss": "Add. 11,614"},
    {"name": "Historia Regum Britanniae", "page": 247, "mss": "Add. 11,702. ff. 11-88"},
    {"name": "Roman de la Rose", "page": 887, "mss": "Add. 12,042"},
    {"name": "Troilus and Cryseyde", "page": 71, "mss": "Add. 12,044"},
    {"name": "Uberto and Philomena", "page": 784, "mss": "Add. 12,196. ff. 1-48 b"},
    {"name": "Turpin's Chronicle", "page": 562, "mss": "Add. 12,213. ff. 1-184 b"},
    {"name": "Tinctoris, Compostella", "page": 951, "mss": "Add. 12,213. ff. 160 b-181 b"},
    {"name": "Meliadus", "page": 364, "mss": "Add. 12,228"},
    {"name": "Roman d'Eneas", "page": 82, "mss": "Add. 14,100"},
    {"name": "Guy of Warwick", "page": 490, "mss": "Add. 14,408. ff. 74-77"},
    {"name": "Filocolo", "page": 716, "mss": "Add. 14,682"},
    {"name": "Hanes Taliesin", "page": 421, "mss": "Add. 14,697. ff. 205-208 b"},
    {"name": "Brut Gruffydd ap Arthur", "page": 258, "mss": "Add. 14,903. ff. 20-177"},
    {"name": "Peredur ab Efrawc", "page": 395, "mss": "Add. 14,907. ff. 149-167"},


    # page 11
    {"name": "Hanes Taliesin", "page": 422, "mss": "Add. 15,002. ff. 144 b-147 b"},
    {"name": "Extracts from Brut y Brenhinoedd", "page": 259, "mss": "Add. 15,003. ff. 1-13"},
    {"name": "Isarles y Ffynnawn", "page": 393, "mss": "Add. 15,035. ff. 57-61"},
    {"name": "Dares Phrygius", "page": 25, "mss": "Add. 15,042"},
    {"name": "Contes et Fabliaux", "page": 804, "mss": "Add. 15,210-15,213"},
    {"name": "Partonopeus de Blois", "page": 698, "mss": "Add. 15,212. ff. 14 b-196 b"},
    {"name": "Blanchandin et Orgueillose d'Amors", "page": 727, "mss": "Add. 15,212. ff. 197-266 b"},
    {"name": "Floire et Blancheflor", "page": 714, "mss": "Add. 15,213"},
    {"name": "Dictys Cretensis", "page": 10, "mss": "Add. 15,429"},
    {"name": "Historia Trojana", "page": 43, "mss": "Add. 15,477"},
    {"name": "Brut Tyailio", "page": 254, "mss": "Add. 15,566. ff. 6-140"},
    {"name": "Les deux Chevaliers, and Le dit de Guillaume d'Angleterre", "page": 757, "mss": "Add. 15,606. ff. 110, col. 2,-113, col. 2; and 140 b-152"},
    {"name": "Historia Regum Britanniae", "page": 234, "mss": "Add. 15,732"},
    {"name": "Roman de la Rose", "page": 894, "mss": "Add. 16,169. ff. 1, 477"},
    {"name": "Roman d'Athis et Profilas", "page": 173, "mss": "Add. 16,441"},
    {"name": "Roman d'Athis et Profilas", "page": 929, "mss": "Add. 16,441"},

    {"name": "Sydrac and Boctus", "page": 903, "mss": "Add. 16,563"},
    {"name": "Voeux du Paon and Restor du Paon", "page": 150, "mss": "Add. 16,888"},
    {"name": "Theseus de Cologne", "page": 769, "mss": "Add. 16,955"},
    {"name": "Voeux du Paon", "page": 146, "mss": "Add. 16,956"},
    {"name": "Alexandreis", "page": 141, "mss": "Add. 17,084"},
    {"name": "Lancelot du Lac", "page": 348, "mss": "Add. 17,443"},
    {"name": "Sydrac and Boctus", "page": 909, "mss": "Add. 17,914"},
    {"name": "Turpin's Chronicle", "page": 592, "mss": "Add. 17,920. ff. 6 b-19 b"},
    {"name": "Alexandreis", "page": 99, "mss": "Add. 18,217"},
    {"name": "Romance of Thebes", "page": 89, "mss": "Add. 18,632. ff. 5-33"},
    {"name": "The Diana of Montemayor", "page": 789, "mss": "Add. 18,688"},
    {"name": "Amis and Amylion", "page": 678, "mss": "Add. 18,922. ff. 204-221 b"},
    {"name": "Turpin's Chronicle", "page": 573, "mss": "Add. 19,513. ff. 141-163"},
    {"name": "Wigalois", "page": 398, "mss": "Add. 19,554. ff. 2-56 b"},
    {"name": "Iwein", "page": 390, "mss": "Add. 19,554. ff. 57-100 b"},
    {"name": "Dares Phrygius", "page": 26, "mss": "Add. 19,709. ff. 1-7"},
    {"name": "Brut Gruffydd ap Arthur", "page": 257, "mss": "Add. 19,709. ff. 8-84"},
    {"name": "May Colvin", "page": 544, "mss": "Add. 20,094. ff. 21-26, 30-32 b"},
    {"name": "Philomena", "page": 596, "mss": "Add. 21,218"},
    {"name": "Filostrato", "page": 67, "mss": "Add. 21,246"},
    {"name": "Historia Trojana", "page": 46, "mss": "Add. 22,155"},
    {"name": "King Robert of Sicily", "page": 763, "mss": "Add. 22,283. ff. 90 b-91 b"},
    {"name": "The King of Tars and the Soudan of Damas", "page": 767, "mss": "Add. 22,283. ff. 126-128 b"},
    {"name": "Scottish Ballads", "page": 531, "mss": "Add. 22,311"},
    {"name": "Reali di Francia", "page": 672, "mss": "Add. 22,312"},
    {"name": "Alexandreis", "page": 96, "mss": "Add. 22,821"},
    {"name": "Tristram", "page": 357, "mss": "Add. 23,829"},
    {"name": "Guiron le Courtois", "page": 369, "mss": "Add. 23,930. ff. 1-87 b"},
    {"name": "Tales and Fables", "page": 826, "mss": "Add. 24,946"},
    #manque le haut de la pagge 12


    {"name": "Nine Romantic Tales", "page": 867, "mss": "Add. 24,969. ff. 25, 62, 69 b, 74, 78 b, 83, 94, 209, 270"},
    {"name": "Alexander saga", "page": 105, "mss": "Add. 24,969. ff. 128 b-151 b"},
    {"name": "Story of Sigurgaror", "page": 871, "mss": "Add. 24,970"},
    {"name": "Fertrams saga", "page": 872, "mss": "Add. 24,972. ff. 58-72 b"},
    {"name": "Two Romantic Tales", "page": 872, "mss": "Add. 24,973. ff. 2-69 b"},
    {"name": "Prophecy of Merlin", "page": 292, "mss": "Add. 25,014. ff. 119 b, col. 2"},
    {"name": "Prophecies de Merlin", "page": 371, "mss": "Add. 25,434"},
    {"name": "The Chaste Duchess", "page": 713, "mss": "Add. 25,569. ff. 15 b-21"},
    {"name": "Romances and Ballads", "page": 817, "mss": "Add. 27,979"},
    {"name": "Robin Hood", "page": 519, "mss": "Add. 27879 ff. 2-10"},
    {"name": "Sir Lancelot of Dulake", "page": 397, "mss": "Add. 27879 ff. 10-14, 16, 17"},
    {"name": "Miscellaneous Ballads", "page": 525, "mss": "Add. 27879 ff. 14 b-24"},
    {"name": "The Grene Knight, Turke and Gowin, The Marriage of Sir Gawaine", "page": 389, "mss": "Add. 27879. ff. 17 b-24 b, 101 b-105, 223 b-226 b"},
    {"name": "Sir Lambewell", "page": 417, "mss": "Add. 27879. ff. 29 b-33 b"},
    {"name": "Merlin", "page": 386, "mss": "Add. 27879 ff. 72 b-89"},
    {"name": "King Arthur's Death", "page": 406, "mss": "Add. 27879 ff. 89, 91"},
    {"name": "Guye and Amarant", "page": 499, "mss": "Add. 27879 ff. 110-117"},
    {"name": "Three Ballads of Forest Life", "page": 523, "mss": "Add. 27879 ff. 117 b-210"},
    {"name": "Guy and Phillis", "page": 500, "mss": "Add. 27879 ff. 126"},
    {"name": "Robin Hood Ballad", "page": 520, "mss": "Add. 27879 ff. 129-180 b"},


    # après ça c'est ok.
    {"name": "Boy and Mantle", "page": 404, "mss": "Add. 27879 ff 140, 141"},
    {"name": "Libius Disconius", "page": 401, "mss": "Add. 27879 ff 156 b-171"},
    {"name": "Guy and Colebrande", "page": 500, "mss": "Add. 27879 ff 172 b-176b"},
    {"name": "Two Ballads relating to Adam Bell", "page": 522, "mss": "Add. 27879 ff 194-201"},
    {"name": "A Propecye", "page": 327, "mss": "Add. 27879 f 239 b"},
    {"name": "King Humber", "page": 339, "mss": "Add. 27879 f 248"},
    {"name": "Robin Hood's Garland", "page": 520, "mss": "Add. 28638"},
    {"name": "Ballads of Scotland", "page": 537, "mss": "Add. 29408, 29409"},
    {"name": "Roman de Troie", "page": 924, "mss": "Add. 30863"},
    {"name": "Voeux du Paon", "page": 926, "mss": "Add. 30864"},
    {"name": "Titurel", "page": 932, "mss": "Add. 30984"},
    {"name": "Titus and Vespasian", "page": 928, "mss": "Add. 31042 ff 50-66"},
    {"name": "Two Charlemagne Romances", "page": 953, "mss": "Add. 31042 ff 66 b-79 b, 82-94"},
    {"name": "Richard Coeur-de-Lion", "page": 944, "mss": "Add. 31042 ff 125-163 b"},
    {"name": "Roman de la Rose", "page": 884, "mss": "Add. 31,840"}
    # page 12 en bas
  ],"Egerton": [
    {"name": "Prophecy of the Tenth Sibyl", "page": 190, "mss": "Egerton 810 ff. 106-109 b"}, 
    {"name": "Roman de la Rose", "page": 879, "mss": "Egerton 881"}, 
    {"name": "Tristram", "page": 362, "mss": "Egerton 989"}, 
    {"name": "Roman de la Rose", "page": 890, "mss": "Egerton 1069"},
    {"name": "Roman de la Rose", "page": 891, "mss": "Egerton 2022"},
    {"name": "Ipomedon and Prothesilaus", "page": 746, "mss": "Egerton 2515 ff. 3-141"} 
    ]
}
# print(index_table.keys())
# with open("../results/index_table.json","w", encoding='utf-8')as f:
#     json.dump(index_table, f, indent=2, ensure_ascii=False)

# %%
## index_table(corrigé manuellement) => index_table_clean
def split_by_ff(s: str):
    if "ff" in s:
        left, right = s.split("ff", 1)
        return left.strip(), "ff" + right.strip()
    return s.strip(), None

index_table_clean={}
for mss_cat, works in index_table.items():
    for work in works:
        title = work['name']
        page = work['page']
        mss_ff = work["mss"]

        mss, ff = split_by_ff(mss_ff)

        if title not in index_table_clean:
            index_table_clean[title] = []# one title=> plu mss!

        index_table_clean[title].append({
            'collection':mss_cat,
            'mss':mss,
            'ff': ff,
            'page': page
        })
    
print(index_table_clean.keys())
with open("../results/index_table_clean1.json","w", encoding='utf-8')as f:
    json.dump(index_table_clean, f, indent=2, ensure_ascii=False)
index_table_clean
# Out:
# dict_keys(['Historia Regum Britanniae', "Turpin's Chronicle", 'Prophecy of Merlin Silvester', 'Dares Phrygius', 'Letters between Alexander and Dindimus', 'Alexandreis', 'Prophecies of Merlin', 'Guy of Warwick', 'Prophecy on Scotland', 'Alexander the Great', 'Prophecy', 'Fulk Fitz-Warin', 'Amya and Amylion', 'Tale of Two Lovers', 'Historia Trojana', 'Story of Troy', 'Prophecy of the Tenth Sibyl', 'Karolellus', 'Roman de Brut', 'Havelok', 'Vita Merlini', 'Prophecies of Merlin Silvester', 'Historia Regum Britannia', 'Apollonius of Tyre', 'Le Chemin de Vaillance', "Livre de l'Ordre de Chevalerie", 'Saint Graal', 'Lancelot du Lac', 'Perceforest', 'Simon de Pouille', 'Aspremont', 'Fierabras', 'Ogier le Danois', 'Quatre fils Aimon', 'Pontus and Sidoine', 'Guy of Warwick and Heraud of Ardennes', 'Knight of the Swan', 'Iliaca', 'Heroica', 'Titus and Vespasian', 'Voyage of Charlemagne to Jerusalem and Constantinople', 'Sydrac and Boctus', 'Sir Gowghter', 'Tale of Gamelyn', 'Recueil des Histoir
# ...

# %% [markdown]
# ## aligner 2 tables :index_table + theme table
# title | author | theme | cycle | collection | mss | ff | page

# %%
import json
import pandas as pd
with open("../results/theme_table_clean.json", 'r', encoding='utf-8')as f:
    theme_table=json.load(f)
print(theme_table.keys())
# Out:
# dict_keys(['Classical Romances', 'British and English Traditions', 'French Traditions', 'Miscellaneous Romance', 'Allegorical and Didactic Romance', 'Appendix'])

# %%
theme_table["Classical Romances"]
# Out:
# [{'title': 'Cycle of Troy: Heroica, by Flavius Philostratus', 'page': '1'},
#  {'title': 'Cycle of Troy: Iliaca, by Joannes Tzetzes', 'page': '2'},
#  {'title': 'Cycle of Troy: Dictys Cretensis', 'page': '9'},
#  {'title': 'Cycle of Troy: Dares Phrygius', 'page': '12'},
#  {'title': "Cycle of Troy: Latin Poems, by Simon Chèvre d'Or, etc",
#   'page': '27'},
#  {'title': 'Cycle of Troy: Roman de Troie, by Benoît de Sainte-More',
#   'page': '35'},
#  {'title': 'Cycle of Troy: Historia Trojana, by Guido delle Colonne',
#   'page': '40'},
#  {'title': 'Cycle of Troy: Trojumanna Saga', 'page': '62'},
#  {'title': 'Cycle of Troy: Rimur af Trojumonnum, by Jon Jonsson',
#   'page': '63'},
#  {'title': 'Cycle of Troy: Recueil, by Raoul Le Fèvre', 'page': '64'},
#  {'title': 'Cycle of Troy: Latin History of Troy', 'page': '66'},
#  {'title': 'Cycle of Troy: Filostrato, by Boccaccio', 'page': '67'},
#  {'title': 'Cycle of Troy: Troilus and Chryseyde, by Chaucer', 'page': '70'},
# ...

# %%
def extract_cycle(s):
    if "cycle" in s.lower():
        left, right = s.split(":", 1)
        return left.strip(), right.strip()
    return None, s.strip()
    
def extract_author(s):
    if ", by" in s:
        left, right = s.split(", by", 1)
        return left.strip(), right.strip()
    return s.strip(), None

def get_short_title(s):
    if '(' in s:
        s=re.sub(r'\s*\(.*?\)', '', s).strip()
        # re.sub(pattern, replacement, string)
        # 0+ space, (, 1+ letters, )
    if "," in s:
        first, rest=s.split(',',1)
        return first

    return s

# s="Cycle of Arthur: Iwein, by Hartmann von Aue"
# s="Life of Harold, king of England"
s="Ricciardetto, by Niccolo Fortiguerra"

cycle, title_author = extract_cycle(s)
title, author =extract_author(title_author)
short_title=get_short_title(title)
print("cycle:",cycle)
print("title:",title)
print('short title:', short_title)
print("author:",author)
# Out:
# cycle: None
# title: Ricciardetto
# short title: Ricciardetto
# author: Niccolo Fortiguerra

# %%
from rapidfuzz import process, fuzz

def get_mss_info(title_theme, index_table_clean, score_cutoff=70):

    # 1. EXACT match
    if title_theme in index_table_clean:
        title_index=title_theme
        return title_index, index_table_clean[title_theme]
    
    # 2. FUZZY match
    result = process.extractOne(
        title_theme,
        index_table_clean.keys(),
        scorer=fuzz.ratio,
        score_cutoff=score_cutoff
    )
    
    if result:
        best_match, score, _ = result
        title_index=best_match
        # print(f"Fuzzy match: {best_match} (score={score})")
        return title_index, index_table_clean[best_match]
    # print(f"[No match] found for {title}")
    return None, []


title="Roman de la Bose"#"Iliaca"#"Heroica"
title, mss_info=get_mss_info(title, index_table_clean)
print(title,len(mss_info))
for info in mss_info:
    print(info)
# Out:
# Roman de la Rose 12
# {'collection': 'Royal', 'mss': '19. A. xviii.', 'ff': None, 'page': 885}
# {'collection': 'Royal', 'mss': '19. B. xii.', 'ff': 'ff. 2-147 b', 'page': 888}
# {'collection': 'Royal', 'mss': '19. B. xiii.', 'ff': None, 'page': 874}
# {'collection': 'Royal', 'mss': '20. A. xvii.', 'ff': None, 'page': 880}
# {'collection': 'Royal', 'mss': '20. D. vii.', 'ff': None, 'page': 889}
# {'collection': 'Harley', 'mss': 'Harley 4425', 'ff': None, 'page': 892}
# {'collection': 'Additional', 'mss': 'Add. 12,042', 'ff': None, 'page': 887}
# {'collection': 'Additional', 'mss': 'Add. 16,169.', 'ff': 'ff. 1, 477', 'page': 894}
# {'collection': 'Additional', 'mss': 'Add. 31,840', 'ff': None, 'page': 884}
# {'collection': 'Egerton', 'mss': 'Egerton 881', 'ff': None, 'page': 879}
# {'collection': 'Egerton', 'mss': 'Egerton 1069', 'ff': None, 'page': 890}
# {'collection': 'Egerton', 'mss': 'Egerton 2022', 'ff': None, 'page': 891}

# %%
## ---match mss info and theme info ---

table_clean=[]
for theme, works in theme_table.items():
    for work in works:
        # ---theme---
        page=work['page'] 
        s=work['title']
        cycle, title_author = extract_cycle(s)
        title_theme, author =extract_author(title_author)
        
        # ---mss---  
        # 高分 exact / near match; 低分 short title match  
        title_index, mss_info=get_mss_info(title_theme, index_table_clean, score_cutoff=80)
        
        if not mss_info:
            short_title_theme=get_short_title(title_theme)
            # print('short title:',short_title)
            title_index, mss_info=get_mss_info(short_title_theme, index_table_clean, score_cutoff=60)

        if not mss_info:
            print(f"[No match] found for {title_theme}")
            data={
                'title_theme':title_theme,
                'title_index':None,
                'author':author,
                'theme':theme,
                'cycle':cycle,
                'collection': None,
                'mss':None,
                'ff': None,
                'page':page
            } 
            table_clean.append(data)
        for info in mss_info:
            data={
                'title_theme':title_theme,
                'title_index':title_index,
                'author':author,
                'theme':theme,
                'cycle':cycle,
                'collection': info.get("collection",None),
                'mss': info.get("mss",None),
                'ff': info.get("ff",None),
                'page':page
            } 
            table_clean.append(data)
# Out:
# [No match] found for Latin Poems
# [No match] found for Recueil
# [No match] found for Adam Bell, and other Ballads of Forest life
# [No match] found for Voyage de Charlemagne
# [No match] found for Chevalier au Cygne
# [No match] found for Diana
# [No match] found for Siege of Milan and Sir Otuel

# %%
##----- add no match in index_table in table_clean!----
table_clean_title_index=set([data['title_index'] for data in table_clean])

index_table_nomatch = {
    title_index: data
    for title_index, data in index_table_clean.items()
    if title_index not in table_clean_title_index
}
print(f"no match title index:\n{index_table_nomatch.keys()}\n")

for title_index, infos in index_table_nomatch.items():
    # print(title_index)
    # print(len(infos))
    for info in infos :
        data={
            'title_theme':None,
            'title_index':title_index,
            'author':None,
            'theme':None,
            'cycle':None,
            'collection': info.get('collection',None),
            'mss':info.get('mss',None),
            'ff': info.get('ff',None),
            'page':info.get('page',None),
        } 
        table_clean.append(data)
        
print(len(table_clean))
print(table_clean)
with open("../results/table_clean.json","w", encoding='utf-8')as f:
    json.dump(table_clean, f, indent=2, ensure_ascii=False)
# Out:
# no match title index:
# ...

# %%
import pandas as pd
df_table=pd.DataFrame(table_clean)
display(df_table.head())
df_table.to_csv("../results/table_clean.csv", index=False)
print(df_table.shape)
# Out:
#         title_theme       title_index                author  \
# 0           Heroica           Heroica  Flavius Philostratus
# 1            Iliaca            Iliaca       Joannes Tzetzes
# 2            Iliaca            Iliaca       Joannes Tzetzes
# 3            Iliaca            Iliaca       Joannes Tzetzes
# 4  Dictys Cretensis  Dictys Cretensis                  None
#
#                 theme          cycle collection                mss  \
# 0  Classical Romances  Cycle of Troy      Royal      16. C. xxiii.
# 1  Classical Romances  Cycle of Troy      Royal   16. C. iv. A. B.
# 2  Classical Romances  Cycle of Troy      Royal  16. D. iii. A. B.
# 3  Classical Romances  Cycle of Troy     Harley       Harley 5662.
# 4  Classical Romances  Cycle of Troy     Harley        Harley 3514
#
#            ff page
# 0  ff. 2-69 b    1
# 1        None    2
# 2        None    2
# 3    ff. 1-56    2
# 4        None    9
# (583, 9)

# %%
df_table[['title_theme','title_index']].isna().value_counts()
# Out:
# title_theme  title_index
# False        False          403
# True         False          173
# False        True             7
# Name: count, dtype: int64
